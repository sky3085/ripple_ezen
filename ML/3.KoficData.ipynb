# %%
import requests
import json

# %%
with open('APIKey/Kofic.json', 'r') as file:
    api = json.load(file)
key = api['key']
url = f"http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.json?key={key}&itemPerPage=100"
req = requests.get(url)
kofic = json.loads(req.text)

# %% [markdown]
# movieList  = 코드 : movieCd 제목 : movieNm, 개봉날짜 openDt, 국적 repNationNm, 장르 repGenreAlt,
# another api
# 감독(null포함), 배우(null포함)

# %%
from tqdm import tqdm

page = range(1, 900)
for pg in tqdm(page):
    url_page = f"&curPage={page}"
    url += url_page
    req = requests.get(url)
    kofic_movie_list = json.loads(req.text)
    kofic_movies = kofic_movie_list['movieList']
    for kofic_movie in kofic_movies:
        movieCd = kofic_movie['movieCd']
        title = kofic_movie['movieNm']
        openDt = kofic_movie['openDt']
        country = kofic_movie['repNationNm']
        genres = kofic_movie['repGenreAlt']
        url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={key}&movieCd={movieCd}"
        req = requests.get(url)
        kofic_movie_detail = json.loads(req.text)
# Out:
# {'movieListResult': {'totCnt': 91461,
#   'source': '영화진흥위원회',
#   'movieList': [{'movieCd': '20226726',
#     'movieNm': '극장판 검정고무신: 컴백홈',
#     'movieNmEn': '',
#     'prdtYear': '2022',
#     'openDt': '',
#     'typeNm': '장편',
#     'prdtStatNm': '기타',
#     'nationAlt': '한국',
#     'genreAlt': '애니메이션',
#     'repNationNm': '한국',
#     'repGenreNm': '애니메이션',
#     'directors': [{'peopleNm': '송요한'}],
#     'companys': []},
#    {'movieCd': '20211792',
#     'movieNm': '헌트',
#     'movieNmEn': 'HUNT',
#     'prdtYear': '2022',
#     'openDt': '20220810',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '한국',
#     'genreAlt': '액션,드라마',
#     'repNationNm': '한국',
#     'repGenreNm': '액션',
#     'directors': [{'peopleNm': '이정재'}],
#     'companys': [{'companyCd': '20157708', 'companyNm': '(주)아티스트스튜디오'},
#      {'companyCd': '20122737', 'companyNm': '(주)사나이픽처스'}]},
#    {'movieCd': '20226739',
#     'movieNm': '고고다이노 극장판: 얼음공룡의 비밀',
#     'movieNmEn': '',
# ...
